# %% [markdown]
# <a href="https://colab.research.google.com/github/dinhngocquan/AI-Fundamentals/blob/main/Chapter1/8_exploratory_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Statistics with Pandas:

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 1.1. Read data into a DataFrame:

# %%
df = pd.read_csv('data_Iris.csv', header='infer')

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
df.tail(3)
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# ## 1.2. Statistics using DataFrame methods:

# %%
df.mean(axis=0, numeric_only=True)
# Out:
# Sepal.Length    5.843333
# Sepal.Width     3.054000
# Petal.Length    3.758667
# Petal.Width     1.198667
# dtype: float64

# %%
df.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.loc[:,'Sepal.Length'].corr(df.loc[:,'Sepal.Width'])
# Out:
# np.float64(-0.10936924995064937)

# %%
df.loc[:,'Sepal.Length'].corr(df.loc[:,'Petal.Length'])
# Out:
# np.float64(0.8717541573048718)

# %%
np.round(df.select_dtypes(include=np.number).corr(),3)
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length         1.000       -0.109         0.872        0.818
# Sepal.Width         -0.109        1.000        -0.421       -0.357
# Petal.Length         0.872       -0.421         1.000        0.963
# Petal.Width          0.818       -0.357         0.963        1.000

# %%
df.select_dtypes(include=np.number).corrwith(df.loc[:,'Petal.Length'])
# Out:
# Sepal.Length    0.871754
# Sepal.Width    -0.420516
# Petal.Length    1.000000
# Petal.Width     0.962757
# dtype: float64

# %% [markdown]
# ## 1.3. Slice and then apply a statistic method:

# %%
df[df.Species=='setosa'].select_dtypes(include=np.number).mean(axis=0)
# Out:
# Sepal.Length    5.006
# Sepal.Width     3.418
# Petal.Length    1.464
# Petal.Width     0.244
# dtype: float64

# %%
df[df.Species=='virginica'].select_dtypes(include=np.number).mean(axis=0)
# Out:
# Sepal.Length    6.588
# Sepal.Width     2.974
# Petal.Length    5.552
# Petal.Width     2.026
# dtype: float64

# %%
df[df.Species=='versicolor'].select_dtypes(include=np.number).mean(axis=0)
# Out:
# Sepal.Length    5.936
# Sepal.Width     2.770
# Petal.Length    4.260
# Petal.Width     1.326
# dtype: float64

# %% [markdown]
# Frequency table:

# %%
df.Species.value_counts()
# Out:
# Species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # 2. Missing values:

# %% [markdown]
# First of all, we purposefully enter the missing values:

# %%
df.iloc[10,0] = np.nan
df.iloc[2,2] = np.nan
df.iloc[17,2] = np.nan
df.iloc[2,3] = np.nan
df.iloc[129,2] = np.nan

# %%
df.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           NaN          NaN  setosa

# %% [markdown]
# ## 2.1. Statistics of the missing values:

# %%
df.count(axis=0)
# Out:
# Sepal.Length    149
# Sepal.Width     150
# Petal.Length    147
# Petal.Width     149
# Species         150
# dtype: int64

# %%
df.drop(columns='Species').mean(axis=0)
# Out:
# Sepal.Length    5.846309
# Sepal.Width     3.054000
# Petal.Length    3.777551
# Petal.Width     1.205369
# dtype: float64

# %%
df.drop(columns='Species').mean(axis=0, skipna=False)
# Out:
# Sepal.Length      NaN
# Sepal.Width     3.054
# Petal.Length      NaN
# Petal.Width       NaN
# dtype: float64

# %% [markdown]
# ## 2.2. Detect and process the missing values:

# %%
(df.isnull()).sum(axis=0)
# Out:
# Sepal.Length    1
# Sepal.Width     0
# Petal.Length    3
# Petal.Width     1
# Species         0
# dtype: int64

# %%
(df.isnull()).mean(axis=0)
# Out:
# Sepal.Length    0.006667
# Sepal.Width     0.000000
# Petal.Length    0.020000
# Petal.Width     0.006667
# Species         0.000000
# dtype: float64

# %%
df2=df.dropna(axis=0)

# %%
df2.shape
# Out:
# (146, 5)

# %%
df2.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa

# %%
df2=df.dropna(axis=0,thresh=4)
df2.shape
# Out:
# (149, 5)

# %%
df3=df.dropna(axis=1)
df3.shape
# Out:
# (150, 2)

# %%
df3.head(3)
# Out:
#    Sepal.Width Species
# 0          3.5  setosa
# 1          3.0  setosa
# 2          3.2  setosa

# %%
df3 = df.dropna(axis=1, thresh = 149)
df3.shape
# Out:
# (150, 4)

# %%
df3.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Width Species
# 0           5.1          3.5          0.2  setosa
# 1           4.9          3.0          0.2  setosa
# 2           4.7          3.2          NaN  setosa

# %% [markdown]
# ## 2.3. Fill the missing values:

# %%
df4=df.fillna(value=0)
df4.count()
# Out:
# Sepal.Length    150
# Sepal.Width     150
# Petal.Length    150
# Petal.Width     150
# Species         150
# dtype: int64

# %%
df['Sepal.Length'] = df['Sepal.Length'].fillna(value=df['Sepal.Length'].mean())
df['Petal.Length'] = df['Petal.Length'].fillna(value=df['Petal.Length'].mean())
df['Petal.Width'] = df['Petal.Width'].fillna(value=df['Petal.Width'].mean())
df.count()
# Out:
# Sepal.Length    150
# Sepal.Width     150
# Petal.Length    150
# Petal.Width     150
# Species         150
# dtype: int64

# %%
df.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5      1.400000     0.200000  setosa
# 1           4.9          3.0      1.400000     0.200000  setosa
# 2           4.7          3.2      3.777551     1.205369  setosa
