# %% [markdown]
# <a href="https://colab.research.google.com/github/dinhngocquan/AI-Fundamentals/blob/main/Chapter1/9_pandas_multiindex_groupby_pivot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. MultiIndex:

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 1.1. Creating a DataFrame with MultiIndex:

# %%
my_header = ['A','B','C']

# %%
my_index_out = ['G1']*2 + ['G2']*2 + ['G3']*2
my_index_in = ['a', 'b']*3

# %%
my_index_zipped=list(zip(my_index_out,my_index_in))
my_index_zipped
# Out:
# [('G1', 'a'), ('G1', 'b'), ('G2', 'a'), ('G2', 'b'), ('G3', 'a'), ('G3', 'b')]

# %%
my_multi_index=pd.MultiIndex.from_tuples(my_index_zipped)
df=pd.DataFrame(data=np.random.randn(6,3),index=my_multi_index,columns=my_header)

# %%
df
# Out:
#              A         B         C
# G1 a  1.737932  0.537627 -0.913315
#    b -0.745010 -0.286342 -3.523996
# G2 a  0.054098  0.198036 -0.148715
#    b -1.458668  0.556076 -0.392248
# G3 a -0.510772  0.807545 -0.943803
#    b -1.176243 -1.032314  0.811763

# %% [markdown]
# ## 1.2. Indexing and slicing DataFrames with MultiIndex:

# %%
df.loc['G1']
# Out:
#           A         B         C
# a  1.737932  0.537627 -0.913315
# b -0.745010 -0.286342 -3.523996

# %%
df.loc['G1'].loc['a']
# Out:
# A    1.737932
# B    0.537627
# C   -0.913315
# Name: a, dtype: float64

# %%
df.loc['G1'].loc['a','B']
# Out:
# np.float64(0.5376274574579339)

# %% [markdown]
# # 2. DataFrame summarization:

# %% [markdown]
# ## 2.1. Group by method:

# %%
df = pd.read_csv('data_studentlist.csv',header='infer')

# %%
df.head(3)
# Out:
#              name gender  age  grade absence bloodtype  height  weight
# 0   Jared Diamond      M   23      3       Y         O   165.3    68.2
# 1  Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 2    Brian Martin      M   24      4       N         B   175.0    80.1

# %%
df.groupby('gender')['height'].mean()
# Out:
# gender
# F    166.642857
# M    172.410000
# Name: height, dtype: float64

# %%
df.groupby('gender')[['height','weight']].mean()
# Out:
#             height     weight
# gender
# F       166.642857  50.442857
# M       172.410000  68.500000

# %%
df.groupby('gender')[['grade','age']].std()
# Out:
#            grade       age
# gender
# F       0.755929  1.069045
# M       1.159502  1.159502

# %%
df.groupby('gender')['height'].describe()
# Out:
#         count        mean       std    min      25%    50%    75%    max
# gender
# F         7.0  166.642857  8.487414  155.2  160.100  168.0  173.1  176.9
# M        10.0  172.410000  6.804647  162.2  167.475  172.1  177.9  182.1

# %%
sr=df.groupby(['gender','bloodtype'])['height'].mean()
sr
# Out:
# gender  bloodtype
# F       A            172.450000
#         AB           170.100000
#         B            158.200000
#         O            164.433333
# M       A            165.700000
#         AB           181.050000
#         B            174.550000
#         O            166.200000
# Name: height, dtype: float64

# %%
sr.loc['F']

# %%
sr.loc['F'].loc['A']
# Out:
# np.float64(172.45)

# %% [markdown]
# ## 2.2. DataFrame methods:

# %%
df['height'].apply(lambda x:x/100)
# Out:
# 0     1.653
# 1     1.701
# 2     1.750
# 3     1.821
# 4     1.680
# 5     1.620
# 6     1.552
# 7     1.769
# 8     1.785
# 9     1.761
# 10    1.671
# 11    1.800
# 12    1.622
# 13    1.761
# 14    1.582
# 15    1.686
# 16    1.692
# Name: height, dtype: float64

# %%
df.sort_values(by='bloodtype')
# Out:
#                 name gender  age  grade absence bloodtype  height  weight
# 16       Andrew King      M   21      1       N         A   169.2    62.2
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 13  Rebecah Anderson      F   23      3       N         O   176.1    53.1
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2

# %%
df.sort_values(by='bloodtype', ascending=False)
# Out:
#                 name gender  age  grade absence bloodtype  height  weight
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2
# 13  Rebecah Anderson      F   23      3       N         O   176.1    53.1
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 16       Andrew King      M   21      1       N         A   169.2    62.2

# %%
df.sort_values(by=['bloodtype','gender'])
# Out:
#                 name gender  age  grade absence bloodtype  height  weight
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 16       Andrew King      M   21      1       N         A   169.2    62.2
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 13  Rebecah Anderson      F   23      3       N         O   176.1    53.1
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0

# %%
df['bloodtype'].unique()
# Out:
# array(['O', 'AB', 'B', 'A'], dtype=object)

# %%
df['bloodtype'].nunique()
# Out:
# 4

# %%
df['bloodtype'].value_counts()
# Out:
# bloodtype
# O     5
# B     5
# A     4
# AB    3
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# M    10
# F     7
# Name: count, dtype: int64

# %% [markdown]
# ## 2.3. Pivoting:

# %%
my_dict = {"Size": ["L", "L", "M", "M", "M", "S", "S", "S", "S"],
           "Type": ["A", "A", "A", "B", "B", "A", "A", "B", "B"],
            "Location": ["L1", "L1", "L1", "L2", "L2", "L1", "L2", "L2", "L1"],
            "A": [1, 2, 2, 3, 3, 4, 5, 6, 7],
            "B": [2, 4, 5, 5, 6, 6, 8, 9, 9]}
df = pd.DataFrame(my_dict)
df
# Out:
#   Size Type Location  A  B
# 0    L    A       L1  1  2
# 1    L    A       L1  2  4
# 2    M    A       L1  2  5
# 3    M    B       L2  3  5
# 4    M    B       L2  3  6
# 5    S    A       L1  4  6
# 6    S    A       L2  5  8
# 7    S    B       L2  6  9
# 8    S    B       L1  7  9

# %%
dfr = pd.pivot_table(df, index=['Size','Type'], columns='Location', values='B')
dfr
# Out:
# Location    L1   L2
# Size Type
# L    A     3.0  NaN
# M    A     5.0  NaN
#      B     NaN  5.5
# S    A     6.0  8.0
#      B     9.0  9.0

# %%
dfr.columns
# Out:
# Index(['L1', 'L2'], dtype='object', name='Location')

# %%
dfr.index
# Out:
# MultiIndex([('L', 'A'),
#             ('M', 'A'),
#             ('M', 'B'),
#             ('S', 'A'),
#             ('S', 'B')],
#            names=['Size', 'Type'])

# %%
pd.pivot_table(df, index=['Size','Type'], columns='Location', values='B', fill_value=0)
# Out:
# Location    L1   L2
# Size Type
# L    A     3.0  0.0
# M    A     5.0  0.0
#      B     0.0  5.5
# S    A     6.0  8.0
#      B     9.0  9.0

# %%
pd.pivot_table(df, index=['Size','Type'], columns='Location', values='B', aggfunc = np.mean, fill_value=0)
# Out:
# /tmp/ipython-input-2902245159.py:1: FutureWarning: The provided callable <function mean at 0x7bd090351c60> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pd.pivot_table(df, index=['Size','Type'], columns='Location', values='B', aggfunc = np.mean, fill_value=0)
# Location    L1   L2
# Size Type
# L    A     3.0  0.0
# M    A     5.0  0.0
#      B     0.0  5.5
# S    A     6.0  8.0
#      B     9.0  9.0

# %%
dfr = pd.pivot_table(df, index='Location', columns=['Size','Type'], values='B')
dfr
# Out:
# Size        L    M         S
# Type        A    A    B    A    B
# Location
# L1        3.0  5.0  NaN  6.0  9.0
# L2        NaN  NaN  5.5  8.0  9.0

# %%
dfr.index
# Out:
# Index(['L1', 'L2'], dtype='object', name='Location')

# %%
dfr.columns
# Out:
# MultiIndex([('L', 'A'),
#             ('M', 'A'),
#             ('M', 'B'),
#             ('S', 'A'),
#             ('S', 'B')],
#            names=['Size', 'Type'])

# %%
pd.pivot_table(df, index=['Size','Type'], columns='Location', values='B', aggfunc = np.median, fill_value=0)
# Out:
# /tmp/ipython-input-424250052.py:1: FutureWarning: The provided callable <function median at 0x7bd08d79df80> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   pd.pivot_table(df, index=['Size','Type'], columns='Location', values='B', aggfunc = np.median, fill_value=0)
# Location    L1   L2
# Size Type
# L    A     3.0  0.0
# M    A     5.0  0.0
#      B     0.0  5.5
# S    A     6.0  8.0
#      B     9.0  9.0

# %%
pd.pivot_table(df, index=['Size','Type'], values=['A','B'], aggfunc=np.mean)
# Out:
# /tmp/ipython-input-2269344164.py:1: FutureWarning: The provided callable <function mean at 0x7bd090351c60> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pd.pivot_table(df, index=['Size','Type'], values=['A','B'], aggfunc=np.mean)
#              A    B
# Size Type
# L    A     1.5  3.0
# M    A     2.0  5.0
#      B     3.0  5.5
# S    A     4.5  7.0
#      B     6.5  9.0

# %%
df.groupby(['Size','Type'])[['A','B']].mean()
# Out:
#              A    B
# Size Type
# L    A     1.5  3.0
# M    A     2.0  5.0
#      B     3.0  5.5
# S    A     4.5  7.0
#      B     6.5  9.0

# %%
pd.pivot_table(df, index=['Size','Type'], values=['A','B'], aggfunc={'A':np.max,'B':np.min})
# Out:
# /tmp/ipython-input-3528825465.py:1: FutureWarning: The provided callable <function max at 0x7bd090351260> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   pd.pivot_table(df, index=['Size','Type'], values=['A','B'], aggfunc={'A':np.max,'B':np.min})
# /tmp/ipython-input-3528825465.py:1: FutureWarning: The provided callable <function min at 0x7bd0903513a0> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   pd.pivot_table(df, index=['Size','Type'], values=['A','B'], aggfunc={'A':np.max,'B':np.min})
#            A  B
# Size Type
# L    A     2  2
# M    A     2  5
#      B     3  5
# S    A     5  6
#      B     7  9
